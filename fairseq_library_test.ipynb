# %% [markdown]
# <a href="https://colab.research.google.com/github/Amplil/nlp-test/blob/master/opmnt_library_transformer_translate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 初期化

# %%
cd "/content/drive/MyDrive/Colab Notebooks"
# Out:
# /content/drive/.shortcut-targets-by-id/1liJWbv2EhngAj7pixTjzRpv9B-Bz9zCt/Colab Notebooks

# %%
ls
# Out:
# CODE_OF_CONDUCT.md  eval_lm.py    fairseq_logo.png  score.py  validate.py
# CONTRIBUTING.md     examples/     generate.py       scripts/
# LICENSE             fairseq/      hubconf.py        setup.py
# README.md           fairseq.gif   interactive.py    tests/
# docs/               fairseq_cli/  preprocess.py     train.py

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/packages")
import slacknotice # オリジナルモジュール

# %%
#!git clone https://github.com/pytorch/fairseq
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 30878, done.
# remote: Counting objects: 100% (510/510), done.
# remote: Compressing objects: 100% (313/313), done.
# remote: Total 30878 (delta 217), reused 393 (delta 190), pack-reused 30368
# Receiving objects: 100% (30878/30878), 21.21 MiB | 13.58 MiB/s, done.
# Resolving deltas: 100% (22915/22915), done.

# %%
cd /home/ubuntu
# Out:
# /home/ubuntu

# %%
cd /home/ubuntu/fairseq
# Out:
# /home/ubuntu/fairseq

# %%
#!git checkout c81fed46ac7868c6d80206ff71c6f6cfe93aee22
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# HEAD is now at c81fed46 Back out "[fairseq][PR] Fix bug (the returned value has a dimension mismatch) in label-smoothed-cross-entropy for MoE" (#837)

# %%
# !pip install torch==1.3.1
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting torch==1.3.1
#   Downloading torch-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (734.6 MB)
#      |████████████████████████████████| 734.6 MB 24 kB/s s eta 0:00:01    |███▍                            | 77.2 MB 72.3 MB/s eta 0:00:10     |███████                         | 159.5 MB 72.9 MB/s eta 0:00:08     |█████████████▋                  | 313.3 MB 67.0 MB/s eta 0:00:07�█▎ | 694.8 MB 81.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy in ./anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages (from torch==1.3.1) (1.16.5)
# Installing collected packages: torch
# Successfully installed torch-1.3.1

# %%
# !pip uninstall -y fairseq
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# WARNING: Skipping fairseq as it is not installed.

# %%
cd fairseq
# Out:
# /home/ubuntu/fairseq

# %%
cd /
# Out:
# /

# %%
pwd
# Out:
# '/home/ubuntu'

# %%
# !python3 setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating fairseq.egg-info
# writing fairseq.egg-info/PKG-INFO
# writing dependency_links to fairseq.egg-info/dependency_links.txt
# writing entry points to fairseq.egg-info/entry_points.txt
# writing requirements to fairseq.egg-info/requires.txt
# writing top-level names to fairseq.egg-info/top_level.txt
# writing manifest file 'fairseq.egg-info/SOURCES.txt'
# reading manifest file 'fairseq.egg-info/SOURCES.txt'
# writing manifest file 'fairseq.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.6
# creating build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/generate.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/setup.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/preprocess.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/score.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/eval_lm.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/__init__.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/train.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# copying fairseq_cli/interactive.py -> build/lib.linux-x86_64-3.6/fairseq_cli
# creating build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/sequence_scorer.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/trainer.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/search.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/checkpoint_utils.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/tokenizer.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/registry.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/utils.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/meters.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/hub_utils.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/pdb.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/sequence_generator.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/options.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/distributed_utils.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/binarizer.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/progress_bar.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/legacy_distributed_data_parallel.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/__init__.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/bleu.py -> build/lib.linux-x86_64-3.6/fairseq
# copying fairseq/file_utils.py -> build/lib.linux-x86_64-3.6/fairseq
# creating build/lib.linux-x86_64-3.6/examples
# copying examples/__init__.py -> build/lib.linux-x86_64-3.6/examples
# creating build/lib.linux-x86_64-3.6/tests
# creating build/lib.linux-x86_64-3.6/tests/speech_recognition
# copying tests/speech_recognition/asr_test_base.py -> build/lib.linux-x86_64-3.6/tests/speech_recognition
# copying tests/speech_recognition/test_vggtransformer.py -> build/lib.linux-x86_64-3.6/tests/speech_recognition
# copying tests/speech_recognition/__init__.py -> build/lib.linux-x86_64-3.6/tests/speech_recognition
# copying tests/speech_recognition/test_cross_entropy.py -> build/lib.linux-x86_64-3.6/tests/speech_recognition
# copying tests/speech_recognition/test_collaters.py -> build/lib.linux-x86_64-3.6/tests/speech_recognition
# creating build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/adafactor.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/fairseq_optimizer.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/fp16_optimizer.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/nag.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/adadelta.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/adagrad.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/adamax.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/sgd.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/adam.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# copying fairseq/optim/bmuf.py -> build/lib.linux-x86_64-3.6/fairseq/optim
# creating build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fairseq_encoder.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/transformer.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/lstm.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/multilingual_transformer.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/distributed_fairseq_model.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fconv_lm.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/transformer_lm.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fconv.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/wav2vec.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fairseq_model.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/masked_lm.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fconv_self_att.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/transformer_from_pretrained_xlm.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/composite_encoder.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fairseq_decoder.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/lightconv.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/fairseq_incremental_decoder.py -> build/lib.linux-x86_64-3.6/fairseq/models
# copying fairseq/models/lightconv_lm.py -> build/lib.linux-x86_64-3.6/fairseq/models
# creating build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/label_smoothed_cross_entropy.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/sentence_prediction.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/composite_loss.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/legacy_masked_lm.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/fairseq_criterion.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/masked_lm.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/sentence_ranking.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/cross_entropy.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/adaptive_loss.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# copying fairseq/criterions/binary_cross_entropy.py -> build/lib.linux-x86_64-3.6/fairseq/criterions
# creating build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/multi_corpus_sampled_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/pad_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/concat_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/plasma_utils.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/strip_token_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/prepend_token_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/indexed_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/id_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/noising.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/dictionary.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/raw_label_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/token_block_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/round_robin_zip_datasets.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/transform_eos_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/base_wrapper_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/numel_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/offset_tokens_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/nested_dictionary_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/iterators.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/data_utils.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/language_pair_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/backtranslation_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/truncate_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/monolingual_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/transform_eos_lang_pair_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/sort_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/fairseq_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/mask_tokens_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/list_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/concat_sentences_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/lru_cache_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/num_samples_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# copying fairseq/data/lm_context_window_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data
# creating build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/learned_positional_embedding.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/logsumexp_moe.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/gelu.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/sparse_transformer_sentence_encoder_layer.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/vggblock.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/sparse_multihead_attention.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/unfold.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/conv_tbc.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/beamable_mm.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/sinusoidal_positional_embedding.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/highway.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/positional_embedding.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/character_token_embedder.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/adaptive_input.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/dynamic_convolution.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/transformer_sentence_encoder_layer.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/layer_norm.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/transformer_sentence_encoder.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/linearized_convolution.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/scalar_bias.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/transformer_layer.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/sparse_transformer_sentence_encoder.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/mean_pool_gating_network.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/grad_multiply.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/multihead_attention.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/adaptive_softmax.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/downsampled_multihead_attention.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# copying fairseq/modules/lightweight_convolution.py -> build/lib.linux-x86_64-3.6/fairseq/modules
# creating build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/translation_moe.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/fairseq_task.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/translation.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/multilingual_translation.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/sentence_prediction.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/legacy_masked_lm.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/language_modeling.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/masked_lm.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/cross_lingual_lm.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/sentence_ranking.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/translation_from_pretrained_xlm.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/semisupervised_translation.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# copying fairseq/tasks/audio_pretraining.py -> build/lib.linux-x86_64-3.6/fairseq/tasks
# creating build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/cosine_lr_scheduler.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/triangular_lr_scheduler.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/fairseq_lr_scheduler.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/tri_stage_lr_scheduler.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/reduce_lr_on_plateau.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/inverse_square_root_schedule.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/polynomial_decay_schedule.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# copying fairseq/optim/lr_scheduler/fixed_schedule.py -> build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler
# creating build/lib.linux-x86_64-3.6/fairseq/models/roberta
# copying fairseq/models/roberta/model.py -> build/lib.linux-x86_64-3.6/fairseq/models/roberta
# copying fairseq/models/roberta/hub_interface.py -> build/lib.linux-x86_64-3.6/fairseq/models/roberta
# copying fairseq/models/roberta/alignment_utils.py -> build/lib.linux-x86_64-3.6/fairseq/models/roberta
# copying fairseq/models/roberta/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/models/roberta
# creating build/lib.linux-x86_64-3.6/fairseq/data/audio
# copying fairseq/data/audio/raw_audio_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data/audio
# copying fairseq/data/audio/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/data/audio
# creating build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/sentencepiece_bpe.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/gpt2_bpe_utils.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/fastbpe.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/subword_nmt_bpe.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/nltk_tokenizer.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/space_tokenizer.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/moses_tokenizer.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/hf_bert_bpe.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# copying fairseq/data/encoders/gpt2_bpe.py -> build/lib.linux-x86_64-3.6/fairseq/data/encoders
# creating build/lib.linux-x86_64-3.6/fairseq/data/legacy
# copying fairseq/data/legacy/masked_lm_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data/legacy
# copying fairseq/data/legacy/masked_lm_dictionary.py -> build/lib.linux-x86_64-3.6/fairseq/data/legacy
# copying fairseq/data/legacy/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/data/legacy
# copying fairseq/data/legacy/block_pair_dataset.py -> build/lib.linux-x86_64-3.6/fairseq/data/legacy
# creating build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer
# copying fairseq/modules/lightconv_layer/setup.py -> build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer
# copying fairseq/modules/lightconv_layer/lightconv_layer.py -> build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer
# copying fairseq/modules/lightconv_layer/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer
# copying fairseq/modules/lightconv_layer/cuda_function_gen.py -> build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer
# creating build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer
# copying fairseq/modules/dynamicconv_layer/setup.py -> build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer
# copying fairseq/modules/dynamicconv_layer/__init__.py -> build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer
# copying fairseq/modules/dynamicconv_layer/cuda_function_gen.py -> build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer
# copying fairseq/modules/dynamicconv_layer/dynamicconv_layer.py -> build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer
# creating build/lib.linux-x86_64-3.6/examples/speech_recognition
# copying examples/speech_recognition/infer.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition
# copying examples/speech_recognition/__init__.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition
# creating build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank_tune.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank_options.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank_utils.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/__init__.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank_generate.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank_score_lm.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# copying examples/noisychannel/rerank_score_bw.py -> build/lib.linux-x86_64-3.6/examples/noisychannel
# creating build/lib.linux-x86_64-3.6/examples/speech_recognition/models
# copying examples/speech_recognition/models/__init__.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/models
# copying examples/speech_recognition/models/vggtransformer.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/models
# creating build/lib.linux-x86_64-3.6/examples/speech_recognition/criterions
# copying examples/speech_recognition/criterions/__init__.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/criterions
# copying examples/speech_recognition/criterions/cross_entropy_acc.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/criterions
# creating build/lib.linux-x86_64-3.6/examples/speech_recognition/data
# copying examples/speech_recognition/data/collaters.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/data
# copying examples/speech_recognition/data/asr_dataset.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/data
# copying examples/speech_recognition/data/data_utils.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/data
# copying examples/speech_recognition/data/__init__.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/data
# creating build/lib.linux-x86_64-3.6/examples/speech_recognition/tasks
# copying examples/speech_recognition/tasks/__init__.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/tasks
# copying examples/speech_recognition/tasks/speech_recognition.py -> build/lib.linux-x86_64-3.6/examples/speech_recognition/tasks
# running build_ext
# building 'fairseq.libbleu' extension
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/fairseq
# creating build/temp.linux-x86_64-3.6/fairseq/clib
# creating build/temp.linux-x86_64-3.6/fairseq/clib/libbleu
# gcc -pthread -B /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/include/python3.6m -c fairseq/clib/libbleu/libbleu.cpp -o build/temp.linux-x86_64-3.6/fairseq/clib/libbleu/libbleu.o -std=c++11
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# gcc -pthread -B /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/include/python3.6m -c fairseq/clib/libbleu/module.cpp -o build/temp.linux-x86_64-3.6/fairseq/clib/libbleu/module.o -std=c++11
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# g++ -pthread -shared -B /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/compiler_compat -L/home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib -Wl,-rpath=/home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib -Wl,--no-as-needed -Wl,--sysroot=/ build/temp.linux-x86_64-3.6/fairseq/clib/libbleu/libbleu.o build/temp.linux-x86_64-3.6/fairseq/clib/libbleu/module.o -o build/lib.linux-x86_64-3.6/fairseq/libbleu.cpython-36m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/tests
# creating build/bdist.linux-x86_64/egg/tests/speech_recognition
# copying build/lib.linux-x86_64-3.6/tests/speech_recognition/asr_test_base.py -> build/bdist.linux-x86_64/egg/tests/speech_recognition
# copying build/lib.linux-x86_64-3.6/tests/speech_recognition/test_vggtransformer.py -> build/bdist.linux-x86_64/egg/tests/speech_recognition
# copying build/lib.linux-x86_64-3.6/tests/speech_recognition/__init__.py -> build/bdist.linux-x86_64/egg/tests/speech_recognition
# copying build/lib.linux-x86_64-3.6/tests/speech_recognition/test_cross_entropy.py -> build/bdist.linux-x86_64/egg/tests/speech_recognition
# copying build/lib.linux-x86_64-3.6/tests/speech_recognition/test_collaters.py -> build/bdist.linux-x86_64/egg/tests/speech_recognition
# creating build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/generate.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/setup.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/preprocess.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/score.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/eval_lm.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/__init__.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/train.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# copying build/lib.linux-x86_64-3.6/fairseq_cli/interactive.py -> build/bdist.linux-x86_64/egg/fairseq_cli
# creating build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/sequence_scorer.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/trainer.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/search.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/checkpoint_utils.py -> build/bdist.linux-x86_64/egg/fairseq
# creating build/bdist.linux-x86_64/egg/fairseq/optim
# creating build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/cosine_lr_scheduler.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/triangular_lr_scheduler.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/fairseq_lr_scheduler.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/tri_stage_lr_scheduler.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/reduce_lr_on_plateau.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/inverse_square_root_schedule.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/polynomial_decay_schedule.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/lr_scheduler/fixed_schedule.py -> build/bdist.linux-x86_64/egg/fairseq/optim/lr_scheduler
# copying build/lib.linux-x86_64-3.6/fairseq/optim/adafactor.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/fairseq_optimizer.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/fp16_optimizer.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/nag.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/adadelta.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/adagrad.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/adamax.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/sgd.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/adam.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# copying build/lib.linux-x86_64-3.6/fairseq/optim/bmuf.py -> build/bdist.linux-x86_64/egg/fairseq/optim
# creating build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fairseq_encoder.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/transformer.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/lstm.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/multilingual_transformer.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/distributed_fairseq_model.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fconv_lm.py -> build/bdist.linux-x86_64/egg/fairseq/models
# creating build/bdist.linux-x86_64/egg/fairseq/models/roberta
# copying build/lib.linux-x86_64-3.6/fairseq/models/roberta/model.py -> build/bdist.linux-x86_64/egg/fairseq/models/roberta
# copying build/lib.linux-x86_64-3.6/fairseq/models/roberta/hub_interface.py -> build/bdist.linux-x86_64/egg/fairseq/models/roberta
# copying build/lib.linux-x86_64-3.6/fairseq/models/roberta/alignment_utils.py -> build/bdist.linux-x86_64/egg/fairseq/models/roberta
# copying build/lib.linux-x86_64-3.6/fairseq/models/roberta/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/models/roberta
# copying build/lib.linux-x86_64-3.6/fairseq/models/transformer_lm.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fconv.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/wav2vec.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fairseq_model.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/masked_lm.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fconv_self_att.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/transformer_from_pretrained_xlm.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/composite_encoder.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fairseq_decoder.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/lightconv.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/fairseq_incremental_decoder.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/models/lightconv_lm.py -> build/bdist.linux-x86_64/egg/fairseq/models
# copying build/lib.linux-x86_64-3.6/fairseq/tokenizer.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/registry.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/utils.py -> build/bdist.linux-x86_64/egg/fairseq
# creating build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/label_smoothed_cross_entropy.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/sentence_prediction.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/composite_loss.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/legacy_masked_lm.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/fairseq_criterion.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/masked_lm.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/sentence_ranking.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/cross_entropy.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/adaptive_loss.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/criterions/binary_cross_entropy.py -> build/bdist.linux-x86_64/egg/fairseq/criterions
# copying build/lib.linux-x86_64-3.6/fairseq/meters.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/hub_utils.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/pdb.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/sequence_generator.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/options.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/distributed_utils.py -> build/bdist.linux-x86_64/egg/fairseq
# creating build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/multi_corpus_sampled_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/pad_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/concat_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/plasma_utils.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/strip_token_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/prepend_token_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# creating build/bdist.linux-x86_64/egg/fairseq/data/audio
# copying build/lib.linux-x86_64-3.6/fairseq/data/audio/raw_audio_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data/audio
# copying build/lib.linux-x86_64-3.6/fairseq/data/audio/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/data/audio
# copying build/lib.linux-x86_64-3.6/fairseq/data/indexed_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/id_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/noising.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/dictionary.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/raw_label_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/token_block_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/round_robin_zip_datasets.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/transform_eos_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/base_wrapper_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/numel_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/offset_tokens_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/nested_dictionary_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/iterators.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/data_utils.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/language_pair_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/backtranslation_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/truncate_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/monolingual_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/data
# creating build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/sentencepiece_bpe.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/gpt2_bpe_utils.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/fastbpe.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/subword_nmt_bpe.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/nltk_tokenizer.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/space_tokenizer.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/moses_tokenizer.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/hf_bert_bpe.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/encoders/gpt2_bpe.py -> build/bdist.linux-x86_64/egg/fairseq/data/encoders
# copying build/lib.linux-x86_64-3.6/fairseq/data/transform_eos_lang_pair_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/sort_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/fairseq_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/mask_tokens_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/list_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/concat_sentences_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/lru_cache_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# creating build/bdist.linux-x86_64/egg/fairseq/data/legacy
# copying build/lib.linux-x86_64-3.6/fairseq/data/legacy/masked_lm_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data/legacy
# copying build/lib.linux-x86_64-3.6/fairseq/data/legacy/masked_lm_dictionary.py -> build/bdist.linux-x86_64/egg/fairseq/data/legacy
# copying build/lib.linux-x86_64-3.6/fairseq/data/legacy/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/data/legacy
# copying build/lib.linux-x86_64-3.6/fairseq/data/legacy/block_pair_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data/legacy
# copying build/lib.linux-x86_64-3.6/fairseq/data/num_samples_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/data/lm_context_window_dataset.py -> build/bdist.linux-x86_64/egg/fairseq/data
# copying build/lib.linux-x86_64-3.6/fairseq/binarizer.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/libbleu.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/progress_bar.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/legacy_distributed_data_parallel.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/__init__.py -> build/bdist.linux-x86_64/egg/fairseq
# creating build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/learned_positional_embedding.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/logsumexp_moe.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/gelu.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/sparse_transformer_sentence_encoder_layer.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/vggblock.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/sparse_multihead_attention.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/unfold.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/conv_tbc.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/beamable_mm.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/sinusoidal_positional_embedding.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/highway.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/positional_embedding.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/character_token_embedder.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/adaptive_input.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/dynamic_convolution.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/transformer_sentence_encoder_layer.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/layer_norm.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/transformer_sentence_encoder.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/linearized_convolution.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/scalar_bias.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# creating build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer/setup.py -> build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer/lightconv_layer.py -> build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/lightconv_layer/cuda_function_gen.py -> build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/transformer_layer.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/sparse_transformer_sentence_encoder.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# creating build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer/setup.py -> build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer/cuda_function_gen.py -> build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/dynamicconv_layer/dynamicconv_layer.py -> build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer
# copying build/lib.linux-x86_64-3.6/fairseq/modules/mean_pool_gating_network.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/grad_multiply.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/multihead_attention.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/adaptive_softmax.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/downsampled_multihead_attention.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/modules/lightweight_convolution.py -> build/bdist.linux-x86_64/egg/fairseq/modules
# copying build/lib.linux-x86_64-3.6/fairseq/bleu.py -> build/bdist.linux-x86_64/egg/fairseq
# copying build/lib.linux-x86_64-3.6/fairseq/file_utils.py -> build/bdist.linux-x86_64/egg/fairseq
# creating build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/translation_moe.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/fairseq_task.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/translation.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/multilingual_translation.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/sentence_prediction.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/legacy_masked_lm.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/language_modeling.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/masked_lm.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/cross_lingual_lm.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/sentence_ranking.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/translation_from_pretrained_xlm.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/semisupervised_translation.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/__init__.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# copying build/lib.linux-x86_64-3.6/fairseq/tasks/audio_pretraining.py -> build/bdist.linux-x86_64/egg/fairseq/tasks
# creating build/bdist.linux-x86_64/egg/examples
# creating build/bdist.linux-x86_64/egg/examples/speech_recognition
# creating build/bdist.linux-x86_64/egg/examples/speech_recognition/models
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/models/__init__.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/models
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/models/vggtransformer.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/models
# creating build/bdist.linux-x86_64/egg/examples/speech_recognition/criterions
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/criterions/__init__.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/criterions
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/criterions/cross_entropy_acc.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/criterions
# creating build/bdist.linux-x86_64/egg/examples/speech_recognition/data
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/data/collaters.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/data
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/data/asr_dataset.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/data
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/data/data_utils.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/data
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/data/__init__.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/data
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/infer.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/__init__.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition
# creating build/bdist.linux-x86_64/egg/examples/speech_recognition/tasks
# copying build/lib.linux-x86_64-3.6/examples/speech_recognition/tasks/__init__.py -> build/bdist.linux-x86_64/egg/examples/speech_recognition/tasks
# ...
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/layer_norm.py to layer_norm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/transformer_sentence_encoder.py to transformer_sentence_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/linearized_convolution.py to linearized_convolution.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/scalar_bias.py to scalar_bias.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer/setup.py to setup.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer/lightconv_layer.py to lightconv_layer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/lightconv_layer/cuda_function_gen.py to cuda_function_gen.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/transformer_layer.py to transformer_layer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/sparse_transformer_sentence_encoder.py to sparse_transformer_sentence_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer/setup.py to setup.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer/cuda_function_gen.py to cuda_function_gen.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/dynamicconv_layer/dynamicconv_layer.py to dynamicconv_layer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/mean_pool_gating_network.py to mean_pool_gating_network.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/grad_multiply.py to grad_multiply.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/multihead_attention.py to multihead_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/adaptive_softmax.py to adaptive_softmax.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/downsampled_multihead_attention.py to downsampled_multihead_attention.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/modules/lightweight_convolution.py to lightweight_convolution.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/bleu.py to bleu.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/file_utils.py to file_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/translation_moe.py to translation_moe.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/fairseq_task.py to fairseq_task.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/translation.py to translation.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/multilingual_translation.py to multilingual_translation.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/sentence_prediction.py to sentence_prediction.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/legacy_masked_lm.py to legacy_masked_lm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/language_modeling.py to language_modeling.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/masked_lm.py to masked_lm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/cross_lingual_lm.py to cross_lingual_lm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/sentence_ranking.py to sentence_ranking.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/translation_from_pretrained_xlm.py to translation_from_pretrained_xlm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/semisupervised_translation.py to semisupervised_translation.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/tasks/audio_pretraining.py to audio_pretraining.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/models/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/models/vggtransformer.py to vggtransformer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/criterions/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/criterions/cross_entropy_acc.py to cross_entropy_acc.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/data/collaters.py to collaters.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/data/asr_dataset.py to asr_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/data/data_utils.py to data_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/data/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/infer.py to infer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/tasks/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/speech_recognition/tasks/speech_recognition.py to speech_recognition.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank_tune.py to rerank_tune.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank_options.py to rerank_options.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank_utils.py to rerank_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank.py to rerank.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank_generate.py to rerank_generate.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank_score_lm.py to rerank_score_lm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/noisychannel/rerank_score_bw.py to rerank_score_bw.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/examples/__init__.py to __init__.cpython-36.pyc
# creating stub loader for fairseq/libbleu.cpython-36m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/fairseq/libbleu.py to libbleu.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying fairseq.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fairseq.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fairseq.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fairseq.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fairseq.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying fairseq.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# examples.noisychannel.__pycache__.rerank_generate.cpython-36: module references __file__
# examples.noisychannel.__pycache__.rerank_utils.cpython-36: module references __file__
# examples.speech_recognition.criterions.__pycache__.__init__.cpython-36: module references __file__
# examples.speech_recognition.models.__pycache__.__init__.cpython-36: module references __file__
# examples.speech_recognition.tasks.__pycache__.__init__.cpython-36: module references __file__
# fairseq.__pycache__.bleu.cpython-36: module references __file__
# fairseq.__pycache__.libbleu.cpython-36: module references __file__
# fairseq.__pycache__.utils.cpython-36: module references __file__
# fairseq.criterions.__pycache__.__init__.cpython-36: module references __file__
# fairseq.data.encoders.__pycache__.__init__.cpython-36: module references __file__
# fairseq.models.__pycache__.__init__.cpython-36: module references __file__
# fairseq.optim.__pycache__.__init__.cpython-36: module references __file__
# fairseq.optim.lr_scheduler.__pycache__.__init__.cpython-36: module references __file__
# fairseq.tasks.__pycache__.__init__.cpython-36: module references __file__
# tests.speech_recognition.__pycache__.asr_test_base.cpython-36: module MAY be using inspect.getframeinfo
# creating dist
# creating 'dist/fairseq-0.8.0-py3.6-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing fairseq-0.8.0-py3.6-linux-x86_64.egg
# creating /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fairseq-0.8.0-py3.6-linux-x86_64.egg
# Extracting fairseq-0.8.0-py3.6-linux-x86_64.egg to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Adding fairseq 0.8.0 to easy-install.pth file
# Installing fairseq-eval-lm script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing fairseq-generate script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing fairseq-interactive script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing fairseq-preprocess script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing fairseq-score script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing fairseq-train script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing fairseq-validate script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
#
# Installed /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fairseq-0.8.0-py3.6-linux-x86_64.egg
# Processing dependencies for fairseq==0.8.0
# Searching for sacrebleu
# Reading https://pypi.org/simple/sacrebleu/
# Downloading https://files.pythonhosted.org/packages/fa/63/b3c11f951eafa2dc296862431f29fb12dbe191cb72217cf88ed04c32086b/sacrebleu-2.0.0-py3-none-any.whl#sha256=1acae0221e27c23c4987834fd17b284b4addc6556941c2097c4d618baa2d67af
# Best match: sacrebleu 2.0.0
# Processing sacrebleu-2.0.0-py3-none-any.whl
# Installing sacrebleu-2.0.0-py3-none-any.whl to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Adding sacrebleu 2.0.0 to easy-install.pth file
# Installing sacrebleu script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
#
# Installed /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sacrebleu-2.0.0-py3.6.egg
# Searching for fastBPE
# Reading https://pypi.org/simple/fastBPE/
# Downloading https://files.pythonhosted.org/packages/e1/37/f97181428a5d151501b90b2cebedf97c81b034ace753606a3cda5ad4e6e2/fastBPE-0.1.0.tar.gz#sha256=95eef4be2689e822a918ac4eae3349cd78ca3f28af591afa421f8fac6d4cd889
# Best match: fastBPE 0.1.0
# Processing fastBPE-0.1.0.tar.gz
# Writing /tmp/easy_install-388xvcj0/fastBPE-0.1.0/setup.cfg
# Running fastBPE-0.1.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-388xvcj0/fastBPE-0.1.0/egg-dist-tmp-8wd02sma
# Compiling fastBPE/fastBPE.pyx because it depends on /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/Cython/Includes/libcpp/vector.pxd.
# [1/1] Cythonizing fastBPE/fastBPE.pyx
# /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/easy_install-388xvcj0/fastBPE-0.1.0/fastBPE/fastBPE.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# package init file 'fastBPE/__init__.py' not found (or not a regular file)
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# zip_safe flag not set; analyzing archive contents...
# __pycache__.fastBPE.cpython-36: module references __file__
# creating /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastBPE-0.1.0-py3.6-linux-x86_64.egg
# Extracting fastBPE-0.1.0-py3.6-linux-x86_64.egg to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Adding fastBPE 0.1.0 to easy-install.pth file
#
# Installed /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastBPE-0.1.0-py3.6-linux-x86_64.egg
# Searching for portalocker
# Reading https://pypi.org/simple/portalocker/
# Downloading https://files.pythonhosted.org/packages/63/eb/f84872af6e9312ea2f345b218015a41191cfd37eeba4a4fd228f241c2a75/portalocker-2.3.2-py2.py3-none-any.whl#sha256=d8c9f7c542e768dbef006a3e49875046ca170d2d41ca712080719110bd066cc4
# Best match: portalocker 2.3.2
# Processing portalocker-2.3.2-py2.py3-none-any.whl
# Installing portalocker-2.3.2-py2.py3-none-any.whl to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Adding portalocker 2.3.2 to easy-install.pth file
#
# Installed /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/portalocker-2.3.2-py3.6.egg
# Searching for tqdm==4.62.3
# Best match: tqdm 4.62.3
# Adding tqdm 4.62.3 to easy-install.pth file
# Installing tqdm script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for torch==1.10.2
# Best match: torch 1.10.2
# Adding torch 1.10.2 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing convert-onnx-to-caffe2 script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing torchrun script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for regex==2020.11.13
# Best match: regex 2020.11.13
# Adding regex 2020.11.13 to easy-install.pth file
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing f2py3 script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
# Installing f2py3.6 script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for cffi==1.14.5
# Best match: cffi 1.14.5
# Adding cffi 1.14.5 to easy-install.pth file
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for dataclasses==0.8
# Best match: dataclasses 0.8
# Adding dataclasses 0.8 to easy-install.pth file
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for typing-extensions==3.10.0.2
# Best match: typing-extensions 3.10.0.2
# Adding typing-extensions 3.10.0.2 to easy-install.pth file
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for tabulate==0.8.9
# Best match: tabulate 0.8.9
# Adding tabulate 0.8.9 to easy-install.pth file
# Installing tabulate script to /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/bin
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for colorama==0.4.4
# Best match: colorama 0.4.4
# Adding colorama 0.4.4 to easy-install.pth file
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Searching for pycparser==2.20
# Best match: pycparser 2.20
# Adding pycparser 2.20 to easy-install.pth file
#
# Using /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages
# Finished processing dependencies for fairseq==0.8.0

# %%
from fairseq import utils
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-49cb8a7dd707> in <module>()
# ----> 1 from fairseq import utils
#
# ImportError: cannot import name 'utils'

# %%
import fairseq

# %%
import models.transformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-f29cacacdadb> in <module>
# ----> 1 import fairseq.models.transformer
#
# ModuleNotFoundError: No module named 'fairseq.models'

# %%
from fairseq.models.transformer import TransformerModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-cfcceab89b7c> in <module>()
# ----> 1 from fairseq.models.transformer import TransformerModel
#
# ModuleNotFoundError: No module named 'fairseq.models'

# %%
from fairseq.models.transformer import TransformerModel
#from transformer import TransformerModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-c73ee139a516> in <module>()
# ----> 1 from fairseq.models.transformer import TransformerModel
#       2 #from transformer import TransformerModel
#
# ModuleNotFoundError: No module named 'fairseq.models'

# %%
pwd
# Out:
# '/home/ubuntu/fairseq'

# %%
cd /home/ubuntu/jparacrawl-experiments/jparacrawl-finetune
# Out:
# /home/ubuntu/jparacrawl-experiments/jparacrawl-finetune

# %%
model = TransformerModel.from_pretrained('.','./pretrained_model_jaen/base.pretrain.pt','./data-sample-bin/decode')
# Out:
# loading archive file /home/ubuntu/jparacrawl-experiments/jparacrawl-finetune/pretrained_model_jaen
# loading archive file /home/ubuntu/jparacrawl-experiments/jparacrawl-finetune/data-sample-bin/decode
# | [ja] dictionary: 31960 types
# | [en] dictionary: 31968 types
# Namespace(activation_dropout=0.0, activation_fn='relu', adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_input=False, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, arch='transformer', attention_dropout=0.0, best_checkpoint_metric='loss', bpe=None, bucket_cap_mb=25, clip_norm=1.0, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='/home/ubuntu/jparacrawl-experiments/jparacrawl-finetune/data-sample-bin/decode', dataset_impl=None, ddp_backend='no_c10d', decoder_attention_heads=8, decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=2048, decoder_input_dim=512, decoder_layers=6, decoder_learned_pos=False, decoder_normalize_before=False, decoder_output_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method='tcp://localhost:13137', distributed_no_spawn=False, distributed_port=-1, distributed_rank=0, distributed_world_size=8, dropout=0.3, encoder_attention_heads=8, encoder_embed_dim=512, encoder_embed_path=None, encoder_ffn_embed_dim=2048, encoder_layers=6, encoder_learned_pos=False, encoder_normalize_before=False, find_unused_parameters=False, fix_batches_to_gpus=False, fp16=True, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, keep_interval_updates=8, keep_last_epochs=-1, label_smoothing=0.1, lazy_load=False, left_pad_source=False, left_pad_target=False, log_format='simple', log_interval=5, lr=[0.001], lr_scheduler='inverse_sqrt', max_epoch=0, max_sentences=None, max_sentences_valid=None, max_source_positions=1024, max_target_positions=1024, max_tokens=5000, max_tokens_valid=5000, max_update=24000, maximize_best_checkpoint_metric=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=1e-09, no_epoch_checkpoints=True, no_last_checkpoints=False, no_progress_bar=False, no_save=False, no_save_optimizer_state=False, no_token_positional_embeddings=False, num_workers=1, optimizer='adam', optimizer_overrides='{}', raw_text=False, required_batch_size_multiple=8, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='/sougen/morishita/work19/research/project/2019/paracrawl/190903_crawl_model_jaen/train/models/base_baseline_seed1', save_interval=10000000000, save_interval_updates=200, seed=1, sentence_avg=False, share_all_embeddings=False, share_decoder_input_output_embed=False, skip_invalid_size_inputs_valid_test=False, source_lang='ja', target_lang='en', task='translation', tbmf_wrapper=False, tensorboard_logdir='', threshold_loss_scale=None, tokenizer=None, train_subset='train', update_freq=[8], upsample_primary=1, use_bmuf=False, user_dir=None, valid_subset='valid', validate_interval=1000000000, warmup_init_lr=1e-07, warmup_updates=4000, weight_decay=0.0)

# %%
model.translate('▁ トム は 猫 が ほしい の よ 。',beam=5)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-8d05cf73a342> in <module>()
# ----> 1 model.translate('▁ トム は 猫 が ほしい の よ 。',beam=5)
#
# /home/ubuntu/fairseq/fairseq/hub_utils.py in translate(self, sentence, beam, verbose, **kwargs)
#     101
#     102     def translate(self, sentence: str, beam: int = 5, verbose: bool = False, **kwargs) -> str:
# --> 103         return self.sample(sentence, beam, verbose, **kwargs)
#     104
#     105     def sample(self, sentence: str, beam: int = 1, verbose: bool = False, **kwargs) -> str:
#
# /home/ubuntu/fairseq/fairseq/hub_utils.py in sample(self, sentence, beam, verbose, **kwargs)
#     105     def sample(self, sentence: str, beam: int = 1, verbose: bool = False, **kwargs) -> str:
#     106         input = self.encode(sentence)
# --> 107         hypo = self.generate(input, beam, verbose, **kwargs)[0]['tokens']
#     108         return self.decode(hypo)
#     109
#
# /home/ubuntu/fairseq/fairseq/hub_utils.py in generate(self, tokens, beam, verbose, **kwargs)
#     118         generator = self.task.build_generator(gen_args)
#     119
# --> 120         translations = self.task.inference_step(generator, self.models, sample)
#     121
#     122         if verbose:
#
# /home/ubuntu/fairseq/fairseq/tasks/fairseq_task.py in inference_step(self, generator, models, sample, prefix_tokens)
#     242     def inference_step(self, generator, models, sample, prefix_tokens=None):
#     243         with torch.no_grad():
# --> 244             return generator.generate(models, sample, prefix_tokens=prefix_tokens)
#     245
#     246     def update_step(self, num_updates):
#
# /home/ubuntu/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /home/ubuntu/fairseq/fairseq/sequence_generator.py in generate(self, models, sample, prefix_tokens, bos_token, **kwargs)
#     374                 step,
#     375                 lprobs.view(bsz, -1, self.vocab_size),
# --> 376                 scores.view(bsz, beam_size, -1)[:, :, :step],
#     377             )
#     378
#
# /home/ubuntu/fairseq/fairseq/search.py in step(self, step, lprobs, scores)
#      79             out=(self.scores_buf, self.indices_buf),
#      80         )
# ---> 81         torch.div(self.indices_buf, vocab_size, out=self.beams_buf)
#      82         self.indices_buf.fmod_(vocab_size)
#      83         return self.scores_buf, self.indices_buf, self.beams_buf
#
# RuntimeError: result type Float can't be cast to the desired output type Long

# %%
model.translate('▁ トム は 猫 が ほしい の よ 。',beam=5,attention=True)

# %%
tokens =model.encode('▁ トム は 猫 が ほしい の よ 。')

# %%
tokens =model.encode('▁Tom ▁wants ▁a ▁cat .')

# %%
model.extract_features('▁ トム は 猫 が ほしい の よ 。')

# %% [markdown]
# # モデルの読み込み

# %%
import onmt.opts as opts
from onmt.utils.parse import ArgumentParser
#from onmt.opts import dynamic_prepare_opts

parser = ArgumentParser(description='translate.py')
#dynamic_prepare_opts(parser, build_vocab_only=True)
opts.translate_opts(parser)

base_args = (["-model", "data/kftt-data-1.0/run/model_step_15000.pt", "-src", "data/en_sample.txt", "-output", "data/kftt-data-1.0/out.txt", "-gpu", "0", "-verbose","-attn_debug"])
opt, unknown = parser.parse_known_args(base_args)
opt
# Out:
# Namespace(align_debug=False, alpha=0.0, attn_debug=True, avg_raw_probs=False, ban_unk_token=False, batch_size=30, batch_type='sents', beam_size=5, beta=-0.0, block_ngram_repeat=0, coverage_penalty='none', data_type='text', dump_beam='', fp32=False, gpu=0, ignore_when_blocking=[], int8=False, length_penalty='none', log_file='', log_file_level='0', max_length=100, max_sent_length=None, min_length=0, models=['data/kftt-data-1.0/run/model_step_15000.pt'], n_best=1, output='data/kftt-data-1.0/out.txt', phrase_table='', random_sampling_temp=1.0, random_sampling_topk=0, random_sampling_topp=0.0, ratio=-0.0, replace_unk=False, report_align=False, report_time=False, seed=-1, shard_size=10000, src='data/en_sample.txt', src_feats=None, stepwise_penalty=False, tgt=None, tgt_prefix=False, verbose=True)

# %%
from onmt.translate.translator import build_translator

ArgumentParser.validate_translate_opts(opt)
logger = init_logger(opt.log_file)

translator = build_translator(opt, logger=logger, report_score=True)

# %%
"""
# out_fileの作成
if out_file is None:
    out_file = codecs.open(opt.output, "w+", "utf-8")
"""
load_test_model = (
    onmt.decoders.ensemble.load_test_model
    if len(opt.models) > 1
    else onmt.model_builder.load_test_model
)
vocab_fields, model, model_opt = load_test_model(opt) # fields->vocab_fields

scorer = onmt.translate.GNMTGlobalScorer.from_opt(opt)

# %%
#def load_test_model(opt, model_path=None)
"""
from onmt.utils.parse import ArgumentParser
import onmt.inputters as inputters
from onmt.utils.misc import use_gpu

model_path="data/kftt-data-1.0/run/model_step_15000.pt"

checkpoint = torch.load(model_path,map_location=lambda storage, loc: storage)

model_opt = ArgumentParser.ckpt_model_opts(checkpoint['opt'])
ArgumentParser.update_model_opts(model_opt)
ArgumentParser.validate_model_opts(model_opt)
fields = checkpoint['vocab']

# Avoid functionality on inference
model_opt.update_vocab = False

model = onmt.model_builder.build_base_model(model_opt, fields, use_gpu(opt), checkpoint,
                            opt.gpu)
if opt.fp32:
    model.float()
elif opt.int8:
    if opt.gpu >= 0:
        raise ValueError(
            "Dynamic 8-bit quantization is not supported on GPU")
    torch.quantization.quantize_dynamic(model, inplace=True)
model.eval()
model.generator.eval()
"""
# Out:
# '\nfrom onmt.utils.parse import ArgumentParser\nimport onmt.inputters as inputters\nfrom onmt.utils.misc import use_gpu\n\nmodel_path="data/kftt-data-1.0/run/model_step_15000.pt"\n\ncheckpoint = torch.load(model_path,map_location=lambda storage, loc: storage)\n\nmodel_opt = ArgumentParser.ckpt_model_opts(checkpoint[\'opt\'])\nArgumentParser.update_model_opts(model_opt)\nArgumentParser.validate_model_opts(model_opt)\nfields = checkpoint[\'vocab\']\n\n# Avoid functionality on inference\nmodel_opt.update_vocab = False\n\nmodel = onmt.model_builder.build_base_model(model_opt, fields, use_gpu(opt), checkpoint,\n                            opt.gpu)\nif opt.fp32:\n    model.float()\nelif opt.int8:\n    if opt.gpu >= 0:\n        raise ValueError(\n            "Dynamic 8-bit quantization is not supported on GPU")\n    torch.quantization.quantize_dynamic(model, inplace=True)\nmodel.eval()\nmodel.generator.eval()\n'

# %%
model
# Out:
# NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(13639, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(12203, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#     (transformer_layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (1): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (2): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (3): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (4): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (5): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=512, bias=True)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (generator): Sequential(
#     (0): Linear(in_features=512, out_features=12203, bias=True)
#     (1): Cast()
#     (2): LogSoftmax(dim=-1)
#   )
# )

# %%
import onmt.inputters as inputters
src_reader = inputters.str2reader[opt.data_type].from_opt(opt)
tgt_reader = inputters.str2reader["text"].from_opt(opt)

# %%
from onmt.translate.translator import max_tok_len

src_data = {
    "reader": src_reader, # self.src_reader->src_reader
    "data": opt.src, # src->opt.src
    "features": {} # src_feats->{}
}
tgt_data = {
    "reader": tgt_reader, # self.tgt_reader->tgt_reader
    "data": opt.tgt, # tgt->opt.tgt
    "features": {}
}
_readers, _data = inputters.Dataset.config(
    [("src", src_data), ("tgt", tgt_data)]
)

dataset = inputters.Dataset( # data->dataset
    vocab_fields, # self.fields->vocab_fields
    readers=_readers,
    data=_data,
    sort_key=inputters.str2sortkey[opt.data_type], # self->opt
    filter_pred=None, # self._filter_pred -> None
)

data_iter = inputters.OrderedIterator(
    dataset=dataset, # data->dataset
    device="cuda", # self._dev->"cuda"
    batch_size=opt.batch_size, # batch_size->opt.batch_size
    batch_size_fn=max_tok_len if opt.batch_type == "tokens" else None, # batch_type->opt.batch_type
    train=False,
    sort=False,
    sort_within_batch=True,
    shuffle=False,
)

builder = onmt.translate.TranslationBuilder(data=dataset, fields=vocab_fields)

# %% [markdown]
# # アテンションの利用

# %%
from onmt.constants import DefaultTokens
from onmt.utils.misc import tile, set_random_seed, report_matrix

# アテンションデバッグをON->今後はopt.attn_debugを使う
# attn_debug=True
for batch in data_iter:
    batch_data = translator.translate_batch(
        batch, dataset.src_vocabs, opt.attn_debug
    )
    translations = builder.from_batch(batch_data)

    for trans in translations:
        print(trans.log(0))
        
        if opt.attn_debug:
            preds = trans.pred_sents[0]
            preds.append(DefaultTokens.EOS)
            attns = trans.attns[0].tolist()
            if translator.data_type == "text":
                srcs = trans.src_raw
            else:
                srcs = [str(item) for item in range(len(attns[0]))]
            output = report_matrix(srcs, preds, attns)
            if translator.logger:
                translator.logger.info(output)
            else:
                #os.write(1, output.encode("utf-8"))
                print(output)
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/onmt/translate/beam_search.py:282: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   self._batch_index = self.topk_ids // vocab_size
# [2021-11-12 03:37:47,165 INFO]                   Tom      wants          a        cat          .
#      <unk>  0.0810000  0.1024836  0.2358941 *0.3071590  0.2734634
#          は  0.0732654  0.2247687  0.1639529  0.1544976 *0.3835154
#      <unk>  0.0123236  0.0434103  0.2558493 *0.5182254  0.1701914
#          を  0.0581806  0.1314417  0.1406690  0.1174424 *0.5522661
#         求め  0.0094350  0.0870038  0.1193642  0.1103888 *0.6738082
#          た  0.0225705  0.0063565  0.0122755  0.0420761 *0.9167213
#          。  0.0304229  0.0092131  0.0123016  0.0236017 *0.9244607
#       </s>  0.0484912  0.0379364  0.0628432  0.0896175 *0.7611117
# SENT 0: ['Tom', 'wants', 'a', 'cat', '.']
# PRED 0: <unk> は <unk> を 求め た 。
# PRED SCORE: -5.6415

# %%
opt.attn_debug
# Out:
# True
